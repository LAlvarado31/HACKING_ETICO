# %% [markdown]
# INYECCION SQL
#
# Ingresar a Owasp Mulillidae II

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.-Ingresamos una comilla simple en el campo del usuario y una contraseña.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Se visualiza una vulnerabilidad

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Ingresamos el Payload de autenticación forzada, se trata de ingresar en el campo usuario una consulta SQL la cual indica que siempre es verdadera.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Acceso a la cuenta del usuario

# %% [markdown]
# ![image.png](attachment:image.png)
